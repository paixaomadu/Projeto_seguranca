# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
df_dados = pd.read_csv('basedeleg', sep= ';', encoding = 'latin1')
df_dados
# Out:
#        cisp  mes   ano  mes_ano  aisp  risp                            munic  \
# 0         1    1  2003  2003m01     5     1                   Rio de Janeiro
# 1         4    1  2003  2003m01     5     1                   Rio de Janeiro
# 2         5    1  2003  2003m01     5     1                   Rio de Janeiro
# 3         6    1  2003  2003m01     1     1                   Rio de Janeiro
# 4         7    1  2003  2003m01     1     1                   Rio de Janeiro
# ...     ...  ...   ...      ...   ...   ...                              ...
# 16784    94    8  2013  2013m08    10     5                            Piraí
# 16785    95    8  2013  2013m08    10     5                        Vassouras
# 16786    96    8  2013  2013m08    10     5  Miguel Pereira;Paty dos Alferes
# 16787    97    8  2013  2013m08    10     5                           Mendes
# 16788    98    8  2013  2013m08    10     5      Engenheiro Paulo de Frontin
#
# ...

# %%
df_capital= df_dados.loc[df_dados['regiao']== 'Capital'] 
df_capital
# Out:
#        cisp  mes   ano  mes_ano  aisp  risp           munic    mcirc   regiao  \
# 0         1    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 1         4    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 2         5    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 3         6    1  2003  2003m01     1     1  Rio de Janeiro  3304557  Capital
# 4         7    1  2003  2003m01     1     1  Rio de Janeiro  3304557  Capital
# ...     ...  ...   ...      ...   ...   ...             ...      ...      ...
# 16742    40    8  2013  2013m08     9     2  Rio de Janeiro  3304557  Capital
# 16743    41    8  2013  2013m08    18     2  Rio de Janeiro  3304557  Capital
# 16744    42    8  2013  2013m08    31     2  Rio de Janeiro  3304557  Capital
# 16745    43    8  2013  2013m08    27     2  Rio de Janeiro  3304557  Capital
# 16746    44    8  2013  2013m08     3     1  Rio de Janeiro  3304557  Capital
#
# ...

# %%
df_veic = df_dados.loc[df_dados[""]
